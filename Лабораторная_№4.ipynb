# %% [markdown]
# <a href="https://colab.research.google.com/github/blwolhppt/ML/blob/master/%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0%D1%8F_%E2%84%964.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Лабораторная работа №4**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures


x = pd.read_csv("https://raw.githubusercontent.com/koroteevmv/ML_course/main/ML1.2_regression/data/0_x.csv",
                header=None)
y = pd.read_csv("https://raw.githubusercontent.com/koroteevmv/ML_course/main/ML1.2_regression/data/0_y.csv",
                header=None)

data = []


def compar(i):
    print(f'До обучения:[[0]]')
    multiple.fit(x[[i]], y)
    print(f'После обучения:{multiple.coef_}')


def second(i):
    multiple.fit(x[[i]], y)
    plt.scatter(x[i], y)
    data.append(multiple.score(x[[i]], y))
    xx = np.linspace(x[i].min(), x[i].max(), 100).reshape((-1, 1))
    plt.plot(xx, multiple.predict(xx), c='r')

# %% [markdown]
# **0. Сравните коэффициенты парной и множественной регрессии до и после обучения.**

# %%
multiple = LinearRegression()
compar(0)
# Out:
# До обучения:[[0]]
# После обучения:[[22.78111342]]

# %%
multiple = LinearRegression()
compar(1)
# Out:
# До обучения:[[0]]
# После обучения:[[95.52010745]]

# %%
multiple = LinearRegression()
compar(2)
# Out:
# До обучения:[[0]]
# После обучения:[[46.94897635]]

# %%
multiple = LinearRegression()
compar(3)
# Out:
# До обучения:[[0]]
# После обучения:[[23.99882407]]

# %%
multiple = LinearRegression()
compar(4)
# Out:
# До обучения:[[0]]
# После обучения:[[1.49082042]]

# %%
multiple = LinearRegression()
print(f'До обучения:[[0 0 0 0 0]]')
multiple.fit(x, y)
print(f'После обучения:{multiple.coef_}')
# Out:
# До обучения:[[0 0 0 0 0]]
# После обучения:[[15.79537523 93.21521093 37.19410687 31.19129121 -0.23773114]]

# %% [markdown]
# **1. Самостоятельно постройте парные регрессии от каждого атрибута с целевой переменной.**

# %%
multiple = LinearRegression()
second(0)

# %%
multiple = LinearRegression()
second(1)

# %%
multiple = LinearRegression()
second(2)

# %%
multiple = LinearRegression()
second(3)

# %%
multiple = LinearRegression()
second(4)

# %% [markdown]
# **2. Для целевой переменной и каждого из признаков постройте полиномиальную регрессию второго, третьего и десятого порядков. Сделайте вывод о значимости регрессии.**

# %% [markdown]
# **5. Замерьте время обучения полиномиальных моделей с разной степенью полинома. Сделайте вывод.**

# %%
# %%time
multiple = make_pipeline(PolynomialFeatures(2), LinearRegression())
second(0)
# Out:
# CPU times: user 36.4 ms, sys: 0 ns, total: 36.4 ms
# Wall time: 39 ms

# %%
# %%time
multiple = make_pipeline(PolynomialFeatures(3), LinearRegression())
second(0)
# Out:
# CPU times: user 40.8 ms, sys: 0 ns, total: 40.8 ms
# Wall time: 52.7 ms

# %%
# %%time
multiple = make_pipeline(PolynomialFeatures(10), LinearRegression())
second(0)
# Out:
# CPU times: user 32.2 ms, sys: 1.51 ms, total: 33.7 ms
# Wall time: 39.7 ms

# %%
# %%time
multiple = make_pipeline(PolynomialFeatures(2), LinearRegression())
second(1)
# Out:
# CPU times: user 30.7 ms, sys: 1.85 ms, total: 32.6 ms
# Wall time: 38.2 ms

# %%
# %%time
multiple = make_pipeline(PolynomialFeatures(3), LinearRegression())
second(1)
# Out:
# CPU times: user 38.4 ms, sys: 0 ns, total: 38.4 ms
# Wall time: 40.5 ms

# %%
# %%time
multiple = make_pipeline(PolynomialFeatures(10), LinearRegression())
second(1)
# Out:
# CPU times: user 26.9 ms, sys: 533 µs, total: 27.4 ms
# Wall time: 27.9 ms

# %%
# %%time
multiple = make_pipeline(PolynomialFeatures(2), LinearRegression())
second(2)
# Out:
# CPU times: user 164 ms, sys: 0 ns, total: 164 ms
# Wall time: 171 ms

# %%
# %%time
multiple = make_pipeline(PolynomialFeatures(3), LinearRegression())
second(2)
# Out:
# CPU times: user 29.1 ms, sys: 683 µs, total: 29.8 ms
# Wall time: 36.6 ms

# %%
# %%time
multiple = make_pipeline(PolynomialFeatures(10), LinearRegression())
second(2)
# Out:
# CPU times: user 30.6 ms, sys: 22 µs, total: 30.6 ms
# Wall time: 33.7 ms

# %%
# %%time
multiple = make_pipeline(PolynomialFeatures(2), LinearRegression())
second(3)
# Out:
# CPU times: user 40.9 ms, sys: 0 ns, total: 40.9 ms
# Wall time: 51.1 ms

# %%
# %%time
multiple = make_pipeline(PolynomialFeatures(3), LinearRegression())
second(3)
# Out:
# CPU times: user 33.9 ms, sys: 0 ns, total: 33.9 ms
# Wall time: 40.2 ms

# %%
# %%time
multiple = make_pipeline(PolynomialFeatures(10), LinearRegression())
second(3)
# Out:
# CPU times: user 36.5 ms, sys: 0 ns, total: 36.5 ms
# Wall time: 44.9 ms

# %%
# %%time
multiple = make_pipeline(PolynomialFeatures(2), LinearRegression())
second(4)
# Out:
# CPU times: user 44.2 ms, sys: 0 ns, total: 44.2 ms
# Wall time: 57.7 ms

# %%
# %%time
multiple = make_pipeline(PolynomialFeatures(3), LinearRegression())
second(4)
# Out:
# CPU times: user 38.2 ms, sys: 0 ns, total: 38.2 ms
# Wall time: 44 ms

# %%
# %%time
multiple = make_pipeline(PolynomialFeatures(10), LinearRegression())
second(4)
# Out:
# CPU times: user 35.6 ms, sys: 0 ns, total: 35.6 ms
# Wall time: 42.1 ms

# %% [markdown]
# **3. Постройте сводную таблицу показателей точности всех построенных моделей. Сделайте вывод, какие модели переобученнные, какие - недообученные.**

# %%
print(np.resize(data, (5, 3)))
# Out:
# [[0.0436717  0.04376507 0.05035596]
#  [0.76999426 0.77111841 0.77267693]
#  [0.19000787 0.19280164 0.20440945]
#  [0.04794251 0.05031163 0.07266747]
#  [0.00104904 0.0010646  0.04505264]]

# %% [markdown]
# **4. Используйте другие метрики качества регрессионной модели в дополнение к коэффициенту детерминации.**
